# %% [markdown]
# # 📘 CIFAR-10 Image Classification Learning Project
# ## Build and Compare **ANN vs CNN** on CIFAR-10
#
# This notebook is designed for **students and beginners** to learn:
# - How image classification works
# - Why **CNN performs better than ANN**
# - How architecture impacts performance
# - How training strategies improve results
#
# 🎯 **Learning Goal:** Understand the complete DL pipeline by **reading the markdown + running the ready code**.

# %% [markdown]
# # 🧠 Problem Statement
# Build an image classification model on the **CIFAR-10 dataset** using:
#
# 1. **Artificial Neural Network (ANN)**
# 2. **Convolutional Neural Network (CNN)**
#
# Then compare:
# - Accuracy
# - Loss curves
# - Generalization
# - Training strategies (dropout, batch norm, augmentation)
#
# ---
# ### 📦 CIFAR-10 Classes
# Airplane, Automobile, Bird, Cat, Deer, Dog, Frog, Horse, Ship, Truck

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
print("TensorFlow Version:", tf.__version__)
# Out:
# TensorFlow Version: 2.21.0

# %% [markdown]
# # 📥 Load Dataset
# We use **CIFAR-10**, which contains **60,000 color images of size 32×32×3**.
# - 50,000 training images
# - 10,000 test images

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

class_names = [
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck'
]

print("Training Shape:", x_train.shape)
print("Testing Shape:", x_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 28s 0us/step
# Training Shape: (50000, 32, 32, 3)
# Testing Shape: (10000, 32, 32, 3)

# %% [markdown]
# ## Exploratory Data Analysis
#
# Before training models, we inspect the dataset and visualize sample images.

# %% [markdown]
# ## 🖼️ Visualize Sample Images

# %%
plt.figure(figsize=(12,6))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(x_train[i])
    plt.title(class_names[y_train[i][0]])
    plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 🧹 Preprocessing
# We normalize pixel values from **0–255 → 0–1** so training becomes stable.

# %%
x_train_norm = x_train / 255.0
x_test_norm = x_test / 255.0

x_train_flat = x_train_norm.reshape(len(x_train_norm), -1)
x_test_flat = x_test_norm.reshape(len(x_test_norm), -1)

# %% [markdown]
# # 🔹 Part 1: ANN Model
# ANN treats images as **flat vectors**, so it cannot preserve spatial features.
# This helps students understand **why CNN is better for images**.

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %%
ann_model = models.Sequential([
    layers.Dense(512, activation='relu', input_shape=(3072,)),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.Dense(10, activation='softmax')
])

ann_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

ann_history = ann_model.fit(
    x_train_flat, y_train,
    epochs=10,
    validation_split=0.1,
    batch_size=64
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# c:\Users\alok1\CIFAR10_Project\.venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - accuracy: 0.2686 - loss: 1.9989 - val_accuracy: 0.3388 - val_loss: 1.8446
# Epoch 2/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.3308 - loss: 1.8448 - val_accuracy: 0.3614 - val_loss: 1.7848
# Epoch 3/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.3443 - loss: 1.8055 - val_accuracy: 0.3812 - val_loss: 1.7464
# Epoch 4/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.3540 - loss: 1.7712 - val_accuracy: 0.3796 - val_loss: 1.7179
# Epoch 5/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.3611 - loss: 1.7467 - val_accuracy: 0.3902 - val_loss: 1.6978
# Epoch 6/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.3739 - loss: 1.7199 - val_accuracy: 0.4074 - val_loss: 1.6666
# Epoch 7/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.3816 - loss: 1.6992 - val_accuracy: 0.4216 - val_loss: 1.6426
# Epoch 8/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.3871 - loss: 1.6874 - val_accuracy: 0.4134 - val_loss: 1.6465
# Epoch 9/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.3925 - loss: 1.6699 - val_accuracy: 0.4240 - val_loss: 1.6331
# Epoch 10/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.3936 - loss: 1.6717 - val_accuracy: 0.4040 - val_loss: 1.6609

# %%
ann_test_loss, ann_test_acc = ann_model.evaluate(x_test_flat, y_test)
print("ANN Test Accuracy:", ann_test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4150 - loss: 1.6457
# ANN Test Accuracy: 0.41499999165534973

# %% [markdown]
# # 🔹 Part 2: CNN Model
# CNN preserves **spatial relationships** using:
# - Convolution layers
# - Pooling
# - Feature extraction
# - Hierarchical learning
#
# This is why CNN performs much better for image tasks.

# %%
cnn_model = models.Sequential([

    layers.Conv2D(
        32,
        (3,3),
        padding='same',
        activation='relu',
        input_shape=(32,32,3)
    ),

    layers.BatchNormalization(),

    layers.Conv2D(
        32,
        (3,3),
        padding='same',
        activation='relu'
    ),

    layers.MaxPooling2D(),

    layers.Dropout(0.3),

    layers.Conv2D(
        64,
        (3,3),
        padding='same',
        activation='relu'
    ),

    layers.BatchNormalization(),

    layers.Conv2D(
        64,
        (3,3),
        padding='same',
        activation='relu'
    ),

    layers.MaxPooling2D(),

    layers.Dropout(0.3),

    layers.Flatten(),

    layers.Dense(
        256,
        activation='relu'
    ),

    layers.Dropout(0.5),

    layers.Dense(
        10,
        activation='softmax'
    )
])

cnn_model.summary()
# Out:
# c:\Users\alok1\CIFAR10_Project\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 256)            │     1,048,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,117,354 (4.26 MB)
#  Trainable params: 1,117,162 (4.26 MB)
#  Non-trainable params: 192 (768.00 B)

# %%
cnn_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=4,
    restore_best_weights=True
)

# %%
cnn_history = cnn_model.fit(
    x_train_norm,
    y_train,
    epochs=20,
    validation_split=0.1,
    batch_size=64,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 37s 49ms/step - accuracy: 0.3063 - loss: 1.8712 - val_accuracy: 0.4396 - val_loss: 1.5497
# Epoch 2/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 34s 48ms/step - accuracy: 0.4265 - loss: 1.5293 - val_accuracy: 0.5342 - val_loss: 1.2993
# Epoch 3/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 33s 47ms/step - accuracy: 0.5040 - loss: 1.3491 - val_accuracy: 0.6160 - val_loss: 1.0917
# Epoch 4/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 33s 47ms/step - accuracy: 0.5651 - loss: 1.2091 - val_accuracy: 0.6930 - val_loss: 0.8708
# Epoch 5/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 35s 50ms/step - accuracy: 0.6221 - loss: 1.0722 - val_accuracy: 0.5688 - val_loss: 1.2949
# Epoch 6/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 35s 50ms/step - accuracy: 0.6589 - loss: 0.9774 - val_accuracy: 0.7048 - val_loss: 0.8522
# Epoch 7/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 35s 49ms/step - accuracy: 0.6888 - loss: 0.8980 - val_accuracy: 0.7426 - val_loss: 0.7474
# Epoch 8/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 35s 50ms/step - accuracy: 0.7070 - loss: 0.8417 - val_accuracy: 0.7446 - val_loss: 0.7539
# Epoch 9/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 35s 49ms/step - accuracy: 0.7200 - loss: 0.8076 - val_accuracy: 0.7522 - val_loss: 0.7221
# Epoch 10/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 35s 50ms/step - accuracy: 0.7379 - loss: 0.7628 - val_accuracy: 0.7628 - val_loss: 0.6978
# Epoch 11/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 35s 49ms/step - accuracy: 0.7453 - loss: 0.7376 - val_accuracy: 0.7610 - val_loss: 0.7295
# Epoch 12/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 35s 50ms/step - accuracy: 0.7544 - loss: 0.7119 - val_accuracy: 0.7720 - val_loss: 0.6769
# Epoch 13/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 35s 49ms/step - accuracy: 0.7612 - loss: 0.6882 - val_accuracy: 0.7732 - val_loss: 0.6857
# Epoch 14/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 35s 49ms/step - accuracy: 0.7700 - loss: 0.6652 - val_accuracy: 0.7596 - val_loss: 0.7466
# Epoch 15/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 36s 51ms/step - accuracy: 0.7777 - loss: 0.6440 - val_accuracy: 0.7892 - val_loss: 0.6532
# Epoch 16/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 36s 51ms/step - accuracy: 0.7815 - loss: 0.6307 - val_accuracy: 0.7960 - val_loss: 0.6085
# Epoch 17/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 35s 50ms/step - accuracy: 0.7856 - loss: 0.6149 - val_accuracy: 0.7936 - val_loss: 0.6115
# Epoch 18/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 37s 53ms/step - accuracy: 0.7923 - loss: 0.5985 - val_accuracy: 0.7650 - val_loss: 0.7723
# Epoch 19/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 36s 51ms/step - accuracy: 0.7990 - loss: 0.5803 - val_accuracy: 0.7922 - val_loss: 0.6513
# Epoch 20/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 35s 50ms/step - accuracy: 0.8039 - loss: 0.5653 - val_accuracy: 0.7976 - val_loss: 0.6268

# %%
cnn_test_loss, cnn_test_acc = cnn_model.evaluate(x_test_norm, y_test)
print("CNN Test Accuracy:", cnn_test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7801 - loss: 0.6577
# CNN Test Accuracy: 0.7800999879837036

# %% [markdown]
# ## 📈 Compare Learning Curves

# %%
plt.figure(figsize=(10,4))
plt.plot(ann_history.history['val_accuracy'], label='ANN Val Acc')
plt.plot(cnn_history.history['val_accuracy'], label='CNN Val Acc')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("ANN vs CNN Validation Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# # 🚀 Training Strategy Upgrade: Data Augmentation
# This strategy improves generalization by generating transformed images.

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomTranslation(0.1, 0.1),
    layers.RandomContrast(0.1)
])

# %%
aug_cnn_model = models.Sequential([

    data_augmentation,

    layers.Conv2D(32, (3,3), padding='same', activation='relu',
                  input_shape=(32,32,3)),
    layers.BatchNormalization(),

    layers.Conv2D(32, (3,3), padding='same', activation='relu'),
    layers.BatchNormalization(),

    layers.MaxPooling2D(),
    layers.Dropout(0.25),

    layers.Conv2D(64, (3,3), padding='same', activation='relu'),
    layers.BatchNormalization(),

    layers.Conv2D(64, (3,3), padding='same', activation='relu'),
    layers.BatchNormalization(),

    layers.MaxPooling2D(),
    layers.Dropout(0.30),

    layers.Conv2D(128, (3,3), padding='same', activation='relu'),
    layers.BatchNormalization(),

    layers.Conv2D(128, (3,3), padding='same', activation='relu'),
    layers.BatchNormalization(),

    layers.MaxPooling2D(),
    layers.Dropout(0.40),

    layers.Flatten(),

    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.50),

    layers.Dense(10, activation='softmax')
])
# Out:
# c:\Users\alok1\CIFAR10_Project\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
aug_cnn_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

aug_history = aug_cnn_model.fit(
    x_train_norm,
    y_train,
    epochs=30,
    batch_size=64,
    validation_split=0.1,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 71s 93ms/step - accuracy: 0.4078 - loss: 1.7812 - val_accuracy: 0.5360 - val_loss: 1.2869
# Epoch 2/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 61s 86ms/step - accuracy: 0.5605 - loss: 1.2297 - val_accuracy: 0.6440 - val_loss: 1.0074
# Epoch 3/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 59s 83ms/step - accuracy: 0.6278 - loss: 1.0439 - val_accuracy: 0.6876 - val_loss: 0.9228
# Epoch 4/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 60s 85ms/step - accuracy: 0.6682 - loss: 0.9389 - val_accuracy: 0.6848 - val_loss: 0.9514
# Epoch 5/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 61s 86ms/step - accuracy: 0.6977 - loss: 0.8587 - val_accuracy: 0.6742 - val_loss: 0.9751
# Epoch 6/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 60s 86ms/step - accuracy: 0.7169 - loss: 0.8091 - val_accuracy: 0.7486 - val_loss: 0.7457
# Epoch 7/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 60s 86ms/step - accuracy: 0.7351 - loss: 0.7630 - val_accuracy: 0.7708 - val_loss: 0.6648
# Epoch 8/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 60s 85ms/step - accuracy: 0.7478 - loss: 0.7277 - val_accuracy: 0.7712 - val_loss: 0.6759
# Epoch 9/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 59s 84ms/step - accuracy: 0.7590 - loss: 0.6936 - val_accuracy: 0.8088 - val_loss: 0.5615
# Epoch 10/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 60s 85ms/step - accuracy: 0.7674 - loss: 0.6648 - val_accuracy: 0.7876 - val_loss: 0.6292
# Epoch 11/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 59s 84ms/step - accuracy: 0.7754 - loss: 0.6447 - val_accuracy: 0.7790 - val_loss: 0.6466
# Epoch 12/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 62s 89ms/step - accuracy: 0.7836 - loss: 0.6269 - val_accuracy: 0.7840 - val_loss: 0.6472
# Epoch 13/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 60s 85ms/step - accuracy: 0.7917 - loss: 0.6045 - val_accuracy: 0.8202 - val_loss: 0.5229
# Epoch 14/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 82s 84ms/step - accuracy: 0.7991 - loss: 0.5813 - val_accuracy: 0.8268 - val_loss: 0.4955
# Epoch 15/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 60s 86ms/step - accuracy: 0.8060 - loss: 0.5641 - val_accuracy: 0.8278 - val_loss: 0.5206
# Epoch 16/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 60s 86ms/step - accuracy: 0.8066 - loss: 0.5560 - val_accuracy: 0.8338 - val_loss: 0.4692
# Epoch 17/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 62s 89ms/step - accuracy: 0.8142 - loss: 0.5386 - val_accuracy: 0.8580 - val_loss: 0.4206
# Epoch 18/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 66s 93ms/step - accuracy: 0.8159 - loss: 0.5301 - val_accuracy: 0.8338 - val_loss: 0.4745
# Epoch 19/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 61s 86ms/step - accuracy: 0.8206 - loss: 0.5202 - val_accuracy: 0.8354 - val_loss: 0.4953
# Epoch 20/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 61s 87ms/step - accuracy: 0.8228 - loss: 0.5107 - val_accuracy: 0.8458 - val_loss: 0.4419
# Epoch 21/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 59s 84ms/step - accuracy: 0.8266 - loss: 0.4989 - val_accuracy: 0.8632 - val_loss: 0.4122
# Epoch 22/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 59s 84ms/step - accuracy: 0.8299 - loss: 0.4957 - val_accuracy: 0.8058 - val_loss: 0.5852
# Epoch 23/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 57s 81ms/step - accuracy: 0.8312 - loss: 0.4877 - val_accuracy: 0.8392 - val_loss: 0.4620
# Epoch 24/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 59s 84ms/step - accuracy: 0.8342 - loss: 0.4765 - val_accuracy: 0.8538 - val_loss: 0.4323
# Epoch 25/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 58s 82ms/step - accuracy: 0.8414 - loss: 0.4618 - val_accuracy: 0.8644 - val_loss: 0.4133
# Epoch 26/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 59s 84ms/step - accuracy: 0.8410 - loss: 0.4631 - val_accuracy: 0.8688 - val_loss: 0.3946
# Epoch 27/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 59s 84ms/step - accuracy: 0.8416 - loss: 0.4570 - val_accuracy: 0.8762 - val_loss: 0.3671
# Epoch 28/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 57s 82ms/step - accuracy: 0.8443 - loss: 0.4512 - val_accuracy: 0.8674 - val_loss: 0.4029
# Epoch 29/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 59s 84ms/step - accuracy: 0.8484 - loss: 0.4414 - val_accuracy: 0.8708 - val_loss: 0.3853
# Epoch 30/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 58s 82ms/step - accuracy: 0.8493 - loss: 0.4364 - val_accuracy: 0.8780 - val_loss: 0.3560

# %%
aug_test_loss, aug_test_acc = aug_cnn_model.evaluate(
    x_test_norm,
    y_test
)

print("Augmented CNN Test Accuracy:", aug_test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8697 - loss: 0.3817
# Augmented CNN Test Accuracy: 0.869700014591217

# %% [markdown]
# # 📊 Final Comparison Table

# %%
comparison = pd.DataFrame({
    "Model": [
        "ANN",
        "CNN",
        "CNN + Data Augmentation"
    ],
    "Test Accuracy": [
        ann_test_acc,
        cnn_test_acc,
        aug_test_acc
    ]
})

comparison
# Out:
#                      Model  Test Accuracy
# 0                      ANN         0.4150
# 1                      CNN         0.7801
# 2  CNN + Data Augmentation         0.8697

# %% [markdown]
# ## Comparing all the Learning Curves

# %%
plt.figure(figsize=(10,5))

plt.plot(
    ann_history.history['val_accuracy'],
    label='ANN'
)

plt.plot(
    cnn_history.history['val_accuracy'],
    label='CNN'
)

plt.plot(
    aug_history.history['val_accuracy'],
    label='CNN + Augmentation'
)

plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.title("Model Comparison")
plt.legend()
plt.show()

# %% [markdown]
# ## Confusion Matrix

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

predictions = aug_cnn_model.predict(x_test_norm)

predicted_classes = np.argmax(predictions, axis=1)

cm = confusion_matrix(y_test, predicted_classes)

plt.figure(figsize=(10,8))

sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues'
)

plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step

# %% [markdown]
# ## Classification Report

# %%
print(
    classification_report(
        y_test,
        predicted_classes
    )
)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88      1000
#            1       0.93      0.95      0.94      1000
#            2       0.89      0.75      0.81      1000
#            3       0.77      0.73      0.75      1000
#            4       0.87      0.85      0.86      1000
#            5       0.79      0.81      0.80      1000
#            6       0.86      0.93      0.89      1000
#            7       0.91      0.90      0.91      1000
#            8       0.93      0.92      0.92      1000
#            9       0.89      0.95      0.92      1000
#
#     accuracy                           0.87     10000
#    macro avg       0.87      0.87      0.87     10000
# weighted avg       0.87      0.87      0.87     10000

# %% [markdown]
# # Project Conclusion
#
# This project compared ANN and CNN architectures on the CIFAR-10 dataset.
#
# Results:
#
# - ANN achieved around ~40% accuracy.
# - CNN achieved significantly higher accuracy (~78%).
# - CNN with Data Augmentation achieved the best performance(~86%).
# - CNN preserves spatial information through convolution layers.
# - Data augmentation improved generalization and reduced overfitting.
#
# Conclusion:
# CNN is much more effective than ANN for image classification tasks because it can learn spatial features directly from images.

# %% [markdown]
# # 🎓 Student Learning Tasks
# Try these tasks after understanding the notebook:
#
# ### ✅ Beginner Tasks
# 1. Increase ANN layers and observe performance
# 2. Change CNN filters from 32→64→128
# 3. Increase epochs to 20
# 4. Add **EarlyStopping**
# 5. Add **data augmentation training**

# %% [markdown]
# # ✅ Conclusion
# - **ANN works**, but ignores image structure
# - **CNN extracts spatial features**, so it performs significantly better
# - **Training strategies** like dropout, batch norm, and augmentation improve results
# - This project builds strong fundamentals for **computer vision interviews and deep learning projects**
